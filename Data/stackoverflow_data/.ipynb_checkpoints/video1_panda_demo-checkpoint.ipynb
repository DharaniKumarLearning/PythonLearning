# %%
import pandas as pd

# %%
df = pd.read_csv("survey_results_public.csv")  # reading a csv file and creating a dataframe

# %%
df  # if we just say df then the top 5 rows and the bottom 5 rows from the dataframe will get printed
# Out:
#        ResponseId     Q120                      MainBranch  \
# 0               1  I agree                   None of these
# 1               2  I agree  I am a developer by profession
# 2               3  I agree  I am a developer by profession
# 3               4  I agree  I am a developer by profession
# 4               5  I agree  I am a developer by profession
# ...           ...      ...                             ...
# 89179       89180  I agree  I am a developer by profession
# 89180       89181  I agree  I am a developer by profession
# 89181       89182  I agree     I code primarily as a hobby
# 89182       89183  I agree  I am a developer by profession
# 89183       89184  I agree  I am a developer by profession
#
#                       Age                                         Employment  \
# 0         18-24 years old                                                NaN
# 1         25-34 years old                                Employed, full-time
# ...

# %%
df.shape  # shape attribute is used to know the number of rows and columns in the dataframe

# %%
df.info()  # info() method is used to know the number of rows and columns in the dataframe along with the datatypes of columns

# %%
pd.set_option('display.max_columns', 84)  # to set the number of columns to be displayed in the output
pd.set_option('display.max_rows', 78)  # to set the number of rows to be displayed in the output

# %%
schema_df = pd.read_csv("survey_results_schema.csv")

# %%
schema_df

# %%
df.head()  # to print the first 5 rows of the dataframe

# %%
df.head(10)  # to print the first 10 rows of the dataframe

# %%
df.tail()  # to print the last 5 rows in the dataframe

# %%
df.tail(10)  # to print the last 10 rows in the dataframe

# %%
df.columns

# %%
df['Age']  # accessing the Age column in the dataframe

# %%
df['Age'].value_counts()  # displays rows and the number of times it appeared in the dataframe

# %%
df.iloc[10:20,3:5]  # accessing rows and columns from the dataframe using iloc function

# %%
df.loc[[2, 4], "Age"]  # We can pass the slicing as well to the loc function
# The only difference here is the end index is inclusive

# %%
df.loc[40:50, "Age" : "LearnCode"] # we can pass slice index for columns as well
# Out:
#                 Age                                         Employment  \
# 40  18-24 years old                                Employed, full-time
# 41  25-34 years old                                Employed, full-time
# 42  45-54 years old                                Employed, full-time
# 43  18-24 years old                                Employed, full-time
# 44  35-44 years old                                Employed, full-time
# 45  25-34 years old                                Employed, full-time
# 46  25-34 years old                                 Student, full-time
# 47  55-64 years old  Independent contractor, freelancer, or self-em...
# 48  55-64 years old                                Employed, full-time
# 49  25-34 years old  Independent contractor, freelancer, or self-em...
# 50  35-44 years old                                Employed, full-time
#
#                               RemoteWork  \
# 40  Hybrid (some remote, some in-person)
# ...
