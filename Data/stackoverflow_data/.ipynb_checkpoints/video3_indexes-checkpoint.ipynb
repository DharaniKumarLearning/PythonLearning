# %%
import pandas as pd

# %%
df = pd.read_csv("survey_results_public.csv", index_col = "ResponseId") # creating the index while reading the csv data into the dataframe
schema_df = pd.read_csv("survey_results_schema.csv", index_col = "qname")

# %%
df.head()
# Out:
#                Q120                      MainBranch              Age  \
# ResponseId
# 1           I agree                   None of these  18-24 years old
# 2           I agree  I am a developer by profession  25-34 years old
# 3           I agree  I am a developer by profession  45-54 years old
# 4           I agree  I am a developer by profession  25-34 years old
# 5           I agree  I am a developer by profession  25-34 years old
#
#                                                    Employment  \
# ResponseId
# 1                                                         NaN
# 2                                         Employed, full-time
# 3                                         Employed, full-time
# 4                                         Employed, full-time
# 5           Employed, full-time;Independent contractor, fr...
#
#                                       RemoteWork  \
# ResponseId
# 1                                            NaN
# ...

# %%
df.loc[1]
# Out:
# Q120                           I agree
# MainBranch               None of these
# Age                    18-24 years old
# Employment                         NaN
# RemoteWork                         NaN
#                             ...
# ProfessionalTech                   NaN
# Industry                           NaN
# SurveyLength                       NaN
# SurveyEase                         NaN
# ConvertedCompYearly                NaN
# Name: 1, Length: 83, dtype: object

# %%
schema_df = pd.read_csv("survey_results_schema.csv")

# %%
pd.set_option('display.max_rows', 80)

# %%
schema_df.loc["Frequency_3", "question"]
# Out:
# "Encountering knowledge silos (where one individual or team has information that's not shared or distributed with other individuals or teams) at work?"

# %%
schema_df.sort_index()  # to sort the data inside dataframe using index
# Out:
#                          qid  \
# qname
# AIAcc                 QID324
# AIBen                 QID316
# AIDev                 QID328
# AINext                QID320
# AIOpen                QID321
# AISearch              QID327
# AISelect              QID314
# AISent                QID315
# AITool                QID319
# Age                   QID127
# BuyNewTool            QID279
# CodingActivities      QID297
# CompTotal              QID51
# Country                 QID6
# Currency               QID50
# Database              QID262
# DevType                QID31
# EdLevel                QID25
# Employment            QID296
# Frequency             QID290
# Frequency_1           QID290
# Frequency_2           QID290
# Frequency_3           QID290
# ICorPM                QID287
# Industry              QID326
# Knowledge             QID289
# Knowledge_1           QID289
# Knowledge_2           QID289
# Knowledge_3           QID289
# Knowledge_4           QID289
# ...

# %%
schema_df.sort_index(ascending=False)  # to sort the data inside dataframe using index in descending order
# Out:
#                          qid  \
# qname
# YearsCodePro           QID34
# YearsCode              QID32
# WorkExp               QID288
# Webframe              QID264
# ToolsTech             QID275
# TimeSearching         QID291
# TimeAnswering         QID292
# TechList              QID322
# TBranch               QID299
# SurveyLength          QID132
# SurveyEase            QID133
# SOVisitFreq           QID100
# SOTeamsUsage          QID286
# SOPartFreq            QID102
# SOComm                QID106
# SOAccount             QID101
# SOAI                  QID325
# S7                    QID131
# S6                    QID295
# S5                    QID313
# S4                     QID91
# S3                     QID61
# S2                    QID190
# S1                      QID1
# S0                     QID16
# RemoteWork            QID308
# Q310                  QID310
# Q120                  QID312
# PurchaseInfluence     QID278
# ProfessionalTech      QID304
# ...
